# %%
import pandas as pd

# %%
import requests

# %%
API_STARTPOINT = "https://devtest.fueblabs.com/rest/dummy"

# %%
session = requests.Session()
session.auth = ('rajathtest@gmail.com','fueb1')

# %%
r = session.get(url=API_STARTPOINT)

# %%
type(r)
# Out:
# requests.models.Response

# %%
k = r.text

# %%
l = k.splitlines()

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 1

# %%
l
# Out:
# ['{"error":{"message":"HTTP 404 Not Found","http-code":404,"exception":{"class":"javax.ws.rs.NotFoundException","message":"HTTP 404 Not Found","localized-message":"HTTP 404 Not Found"}}}']

# %%
j = "ItemStateChangedEvent"

# %%
m = []

# %%
for i in l:
    if "ItemStateChangedEvent" in i:
        m.append(i)
        print(i)
# Out:
# 2019-12-31T18:02:10,038 | INFO  | safeCall-7       | ItemStateChangedEvent            | 341 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311757 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2019-12-31T18:02:10,687 | INFO  | safeCall-7       | ItemStateChangedEvent            | 341 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311757 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2019-12-31T18:02:11,369 | INFO  | safeCall-7       | ItemStateChangedEvent            | 341 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311757 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2019-12-31T18:08:25,363 | INFO  | safeCall-3       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2019-12-31T18:08:26,415 | INFO  | safeCall-3       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2019-12-31T18:09:14,978 | INFO  | safeCall-3       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L1 changed from ON to OFF
# 2019-12-31T18:09:16,055 | INFO  | safeCall-1       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2019-12-31T18:23:17,157 | INFO  | safeCall-2       | ItemStateChangedEvent            | 346 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2019-12-31T18:23:17,731 | INFO  | safeCall-1       | ItemStateChangedEvent            | 346 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2019-12-31T18:23:19,052 | INFO  | safeCall-2       | ItemStateChangedEvent            | 346 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2019-12-31T18:32:38,052 | INFO  | safeCall-3       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L5 changed from OFF to ON
# 2019-12-31T18:32:38,678 | INFO  | safeCall-3       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L6 changed from OFF to ON
# 2019-12-31T18:32:39,784 | INFO  | safeCall-2       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2019-12-31T18:32:40,740 | INFO  | safeCall-1       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2019-12-31T18:32:41,513 | INFO  | safeCall-3       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2019-12-31T18:40:25,500 | INFO  | safeCall-7       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L1 changed from ON to OFF
# 2019-12-31T18:40:27,121 | INFO  | safeCall-6       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2019-12-31T18:40:27,752 | INFO  | safeCall-5       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2019-12-31T18:40:28,361 | INFO  | safeCall-7       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L4 changed from ON to OFF
# 2020-01-01T15:26:50,285 | INFO  | safeCall-3       | ItemStateChangedEvent            | 376 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011434 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2020-01-01T15:26:50,912 | INFO  | safeCall-2       | ItemStateChangedEvent            | 376 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011434 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-01T15:46:31,365 | INFO  | safeCall-2       | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2020-01-01T15:46:31,935 | INFO  | safeCall-1       | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-01T16:11:22,739 | INFO  | safeCall-8       | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from NULL to 36
# 2020-01-01T16:13:19,278 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 36 to 47
# 2020-01-01T16:13:21,007 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 47 to 85
# 2020-01-01T16:13:22,668 | INFO  | safeCall-12      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 85 to 9
# 2020-01-01T16:13:27,501 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 9 to 19
# 2020-01-01T16:13:29,298 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 19 to 85
# 2020-01-01T16:13:31,717 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 85 to 100
# 2020-01-01T16:13:33,012 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 100 to 85
# 2020-01-01T16:13:33,968 | INFO  | safeCall-10      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 85 to 57
# 2020-01-01T16:23:16,051 | INFO  | safeCall-3       | ItemStateChangedEvent            | 381 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011617 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-01T17:10:51,396 | INFO  | safeCall-6       | ItemStateChangedEvent            | 381 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011617 | 63_fueb1_Switch_L6 changed from ON to OFF
# 2020-01-01T17:10:51,875 | INFO  | safeCall-7       | ItemStateChangedEvent            | 381 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011617 | 63_fueb1_Switch_L6 changed from OFF to ON
# 2020-01-01T17:32:36,507 | INFO  | safeCall-1       | ItemStateChangedEvent            | 385 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011726 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-01T17:32:49,377 | INFO  | safeCall-1       | ItemStateChangedEvent            | 385 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011726 | 63_fueb1_Switch_L1 changed from ON to OFF
# 2020-01-01T17:33:06,426 | INFO  | safeCall-1       | ItemStateChangedEvent            | 385 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011726 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-01T17:46:41,795 | INFO  | safeCall-1       | ItemStateChangedEvent            | 387 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011742 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-01T17:46:49,431 | INFO  | safeCall-2       | ItemStateChangedEvent            | 387 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011742 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-01T18:09:53,436 | INFO  | safeCall-3       | ItemStateChangedEvent            | 391 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011804 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-01T18:10:12,694 | INFO  | safeCall-1       | ItemStateChangedEvent            | 391 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011804 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T12:23:55,702 | INFO  | safeCall-5       | ItemStateChangedEvent            | 398 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021211 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T12:37:52,781 | INFO  | safeCall-1       | ItemStateChangedEvent            | 400 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021232 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T12:54:34,878 | INFO  | safeCall-3       | ItemStateChangedEvent            | 403 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021245 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T13:03:11,780 | INFO  | safeCall-2       | ItemStateChangedEvent            | 407 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T13:03:29,409 | INFO  | safeCall-3       | ItemStateChangedEvent            | 407 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T14:27:38,438 | INFO  | safeCall-3       | ItemStateChangedEvent            | 410 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T14:27:49,550 | INFO  | safeCall-3       | ItemStateChangedEvent            | 410 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T14:32:41,724 | INFO  | safeCall-3       | ItemStateChangedEvent            | 412 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021424 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T14:32:48,879 | INFO  | safeCall-1       | ItemStateChangedEvent            | 412 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021424 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T15:26:44,281 | INFO  | safeCall-3       | ItemStateChangedEvent            | 415 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021521 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T15:27:05,793 | INFO  | safeCall-3       | ItemStateChangedEvent            | 415 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021521 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T15:37:17,124 | INFO  | safeCall-3       | ItemStateChangedEvent            | 418 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021532 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T15:37:24,662 | INFO  | safeCall-1       | ItemStateChangedEvent            | 418 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021532 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T15:43:14,643 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T15:43:34,407 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T15:44:03,092 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-02T15:44:17,703 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L5 changed from ON to OFF
# 2020-01-02T15:44:18,532 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from ON to OFF
# 2020-01-02T16:05:31,495 | INFO  | safeCall-8       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T16:05:31,754 | INFO  | safeCall-8       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T16:05:32,565 | INFO  | safeCall-8       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T16:06:05,019 | INFO  | safeCall-9       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-02T16:07:49,124 | INFO  | safeCall-14      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | dimmer changed from 57 to 69
# 2020-01-02T16:43:54,226 | INFO  | safeCall-18      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from OFF to ON
# 2020-01-02T16:43:58,319 | INFO  | safeCall-17      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from ON to OFF
# 2020-01-02T16:44:06,919 | INFO  | safeCall-19      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from OFF to ON
# 2020-01-02T16:44:07,814 | INFO  | safeCall-17      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from ON to OFF
# 2020-01-02T16:44:15,192 | INFO  | safeCall-19      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L1 changed from ON to OFF
# 2020-01-02T16:44:16,357 | INFO  | safeCall-17      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2020-01-02T17:01:49,512 | INFO  | safeCall-3       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L1 changed from ON to OFF
# 2020-01-02T17:03:25,920 | INFO  | safeCall-10      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer changed from 57 to 4
# 2020-01-02T18:21:02,187 | INFO  | safeCall-10      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from NULL to ON
# 2020-01-02T18:21:03,322 | INFO  | safeCall-11      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF
# 2020-01-02T18:21:06,551 | INFO  | safeCall-12      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON
# 2020-01-02T18:21:07,849 | INFO  | safeCall-12      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF
# 2020-01-02T18:22:54,675 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON
# 2020-01-02T18:22:59,300 | INFO  | safeCall-16      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF
# 2020-01-02T18:23:07,975 | INFO  | safeCall-15      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON
# 2020-01-02T18:23:13,061 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF
# 2020-01-02T18:23:15,508 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON
# 2020-01-02T18:23:18,337 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF
# 2020-01-02T18:23:24,763 | INFO  | safeCall-15      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON
# 2020-01-02T18:33:43,479 | INFO  | safeCall-26      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T18:33:44,782 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T18:33:46,334 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T18:33:47,129 | INFO  | safeCall-25      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T18:33:47,955 | INFO  | safeCall-26      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T18:33:51,081 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T18:33:53,099 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T19:06:36,520 | INFO  | safeCall-34      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer2 changed from NULL to 100
# 2020-01-02T19:06:51,295 | INFO  | safeCall-36      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer2 changed from 100 to 0
# 2020-01-02T19:16:59,802 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2020-01-02T19:17:03,435 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T19:17:05,306 | INFO  | safeCall-3       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T19:17:06,116 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T19:17:14,215 | INFO  | safeCall-3       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T19:17:15,858 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T19:17:16,628 | INFO  | safeCall-2       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T19:17:17,246 | INFO  | safeCall-2       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T19:17:17,921 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-02T19:17:18,558 | INFO  | safeCall-2       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-02T19:17:18,827 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-03T10:32:09,139 | INFO  | safeCall-7       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2020-01-03T11:19:44,013 | INFO  | safeCall-9       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer changed from 4 to 21
# 2020-01-03T11:41:24,725 | INFO  | safeCall-6       | ItemStateChangedEvent            | 432 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031131 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-03T11:43:00,619 | INFO  | safeCall-10      | ItemStateChangedEvent            | 432 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031131 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-03T11:43:37,570 | INFO  | safeCall-9       | ItemStateChangedEvent            | 432 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031131 | dimmer changed from 4 to 23
# 2020-01-03T14:30:01,696 | INFO  | safeCall-5       | ItemStateChangedEvent            | 436 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-03T17:23:08,705 | INFO  | safeCall-3       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-03T17:23:21,879 | INFO  | safeCall-3       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from OFF to ON
# 2020-01-03T17:24:15,558 | INFO  | safeCall-1       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | dimmer changed from 23 to 44
# 2020-01-03T17:24:46,401 | INFO  | safeCall-3       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L5 changed from ON to OFF
# 2020-01-03T17:25:10,622 | INFO  | safeCall-1       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L5 changed from OFF to ON
# 2020-01-03T19:22:55,711 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | dimmer2 changed from NULL to 27
# 2020-01-06T11:51:55,722 | INFO  | safeCall-5       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L1 changed from OFF to ON
# 2020-01-06T12:14:17,366 | INFO  | safeCall-13      | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from NULL to ON
# 2020-01-06T12:30:05,572 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from ON to OFF
# 2020-01-06T12:30:40,255 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:31:03,506 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:31:13,394 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:31:29,325 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:31:44,692 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | dimmer2 changed from NULL to 0
# 2020-01-06T12:32:12,558 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:33:13,343 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:33:17,230 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:33:19,219 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:33:22,459 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:33:43,539 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:34:13,507 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:34:15,446 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:34:21,143 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:34:22,304 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:34:43,627 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:34:53,329 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF
# 2020-01-06T12:34:56,613 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON
# 2020-01-06T12:35:02,885 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF

# %%
len(m)
# Out:
# 138

# %%
m
# Out:
# ['2019-12-31T18:02:10,038 | INFO  | safeCall-7       | ItemStateChangedEvent            | 341 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311757 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2019-12-31T18:02:10,687 | INFO  | safeCall-7       | ItemStateChangedEvent            | 341 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311757 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2019-12-31T18:02:11,369 | INFO  | safeCall-7       | ItemStateChangedEvent            | 341 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311757 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2019-12-31T18:08:25,363 | INFO  | safeCall-3       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2019-12-31T18:08:26,415 | INFO  | safeCall-3       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2019-12-31T18:09:14,978 | INFO  | safeCall-3       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L1 changed from ON to OFF',
#  '2019-12-31T18:09:16,055 | INFO  | safeCall-1       | ItemStateChangedEvent            | 342 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311803 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2019-12-31T18:23:17,157 | INFO  | safeCall-2       | ItemStateChangedEvent            | 346 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2019-12-31T18:23:17,731 | INFO  | safeCall-1       | ItemStateChangedEvent            | 346 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2019-12-31T18:23:19,052 | INFO  | safeCall-2       | ItemStateChangedEvent            | 346 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2019-12-31T18:32:38,052 | INFO  | safeCall-3       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L5 changed from OFF to ON',
#  '2019-12-31T18:32:38,678 | INFO  | safeCall-3       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L6 changed from OFF to ON',
#  '2019-12-31T18:32:39,784 | INFO  | safeCall-2       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2019-12-31T18:32:40,740 | INFO  | safeCall-1       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2019-12-31T18:32:41,513 | INFO  | safeCall-3       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2019-12-31T18:40:25,500 | INFO  | safeCall-7       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L1 changed from ON to OFF',
#  '2019-12-31T18:40:27,121 | INFO  | safeCall-6       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2019-12-31T18:40:27,752 | INFO  | safeCall-5       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2019-12-31T18:40:28,361 | INFO  | safeCall-7       | ItemStateChangedEvent            | 349 - org.eclipse.smarthome.io.monitor - 0.11.0.201912311818 | 63_fueb1_Switch_L4 changed from ON to OFF',
#  '2020-01-01T15:26:50,285 | INFO  | safeCall-3       | ItemStateChangedEvent            | 376 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011434 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2020-01-01T15:26:50,912 | INFO  | safeCall-2       | ItemStateChangedEvent            | 376 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011434 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-01T15:46:31,365 | INFO  | safeCall-2       | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2020-01-01T15:46:31,935 | INFO  | safeCall-1       | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-01T16:11:22,739 | INFO  | safeCall-8       | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from NULL to 36',
#  '2020-01-01T16:13:19,278 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 36 to 47',
#  '2020-01-01T16:13:21,007 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 47 to 85',
#  '2020-01-01T16:13:22,668 | INFO  | safeCall-12      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 85 to 9',
#  '2020-01-01T16:13:27,501 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 9 to 19',
#  '2020-01-01T16:13:29,298 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 19 to 85',
#  '2020-01-01T16:13:31,717 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 85 to 100',
#  '2020-01-01T16:13:33,012 | INFO  | safeCall-11      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 100 to 85',
#  '2020-01-01T16:13:33,968 | INFO  | safeCall-10      | ItemStateChangedEvent            | 379 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011538 | dimmer changed from 85 to 57',
#  '2020-01-01T16:23:16,051 | INFO  | safeCall-3       | ItemStateChangedEvent            | 381 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011617 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-01T17:10:51,396 | INFO  | safeCall-6       | ItemStateChangedEvent            | 381 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011617 | 63_fueb1_Switch_L6 changed from ON to OFF',
#  '2020-01-01T17:10:51,875 | INFO  | safeCall-7       | ItemStateChangedEvent            | 381 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011617 | 63_fueb1_Switch_L6 changed from OFF to ON',
#  '2020-01-01T17:32:36,507 | INFO  | safeCall-1       | ItemStateChangedEvent            | 385 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011726 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-01T17:32:49,377 | INFO  | safeCall-1       | ItemStateChangedEvent            | 385 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011726 | 63_fueb1_Switch_L1 changed from ON to OFF',
#  '2020-01-01T17:33:06,426 | INFO  | safeCall-1       | ItemStateChangedEvent            | 385 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011726 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-01T17:46:41,795 | INFO  | safeCall-1       | ItemStateChangedEvent            | 387 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011742 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-01T17:46:49,431 | INFO  | safeCall-2       | ItemStateChangedEvent            | 387 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011742 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-01T18:09:53,436 | INFO  | safeCall-3       | ItemStateChangedEvent            | 391 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011804 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-01T18:10:12,694 | INFO  | safeCall-1       | ItemStateChangedEvent            | 391 - org.eclipse.smarthome.io.monitor - 0.11.0.202001011804 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T12:23:55,702 | INFO  | safeCall-5       | ItemStateChangedEvent            | 398 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021211 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T12:37:52,781 | INFO  | safeCall-1       | ItemStateChangedEvent            | 400 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021232 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T12:54:34,878 | INFO  | safeCall-3       | ItemStateChangedEvent            | 403 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021245 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T13:03:11,780 | INFO  | safeCall-2       | ItemStateChangedEvent            | 407 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T13:03:29,409 | INFO  | safeCall-3       | ItemStateChangedEvent            | 407 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T14:27:38,438 | INFO  | safeCall-3       | ItemStateChangedEvent            | 410 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T14:27:49,550 | INFO  | safeCall-3       | ItemStateChangedEvent            | 410 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021258 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T14:32:41,724 | INFO  | safeCall-3       | ItemStateChangedEvent            | 412 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021424 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T14:32:48,879 | INFO  | safeCall-1       | ItemStateChangedEvent            | 412 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021424 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T15:26:44,281 | INFO  | safeCall-3       | ItemStateChangedEvent            | 415 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021521 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T15:27:05,793 | INFO  | safeCall-3       | ItemStateChangedEvent            | 415 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021521 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T15:37:17,124 | INFO  | safeCall-3       | ItemStateChangedEvent            | 418 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021532 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T15:37:24,662 | INFO  | safeCall-1       | ItemStateChangedEvent            | 418 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021532 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T15:43:14,643 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T15:43:34,407 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T15:44:03,092 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-02T15:44:17,703 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L5 changed from ON to OFF',
#  '2020-01-02T15:44:18,532 | INFO  | safeCall-3       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from ON to OFF',
#  '2020-01-02T16:05:31,495 | INFO  | safeCall-8       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T16:05:31,754 | INFO  | safeCall-8       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T16:05:32,565 | INFO  | safeCall-8       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T16:06:05,019 | INFO  | safeCall-9       | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-02T16:07:49,124 | INFO  | safeCall-14      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | dimmer changed from 57 to 69',
#  '2020-01-02T16:43:54,226 | INFO  | safeCall-18      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from OFF to ON',
#  '2020-01-02T16:43:58,319 | INFO  | safeCall-17      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from ON to OFF',
#  '2020-01-02T16:44:06,919 | INFO  | safeCall-19      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from OFF to ON',
#  '2020-01-02T16:44:07,814 | INFO  | safeCall-17      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L6 changed from ON to OFF',
#  '2020-01-02T16:44:15,192 | INFO  | safeCall-19      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L1 changed from ON to OFF',
#  '2020-01-02T16:44:16,357 | INFO  | safeCall-17      | ItemStateChangedEvent            | 421 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021538 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2020-01-02T17:01:49,512 | INFO  | safeCall-3       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L1 changed from ON to OFF',
#  '2020-01-02T17:03:25,920 | INFO  | safeCall-10      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer changed from 57 to 4',
#  '2020-01-02T18:21:02,187 | INFO  | safeCall-10      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from NULL to ON',
#  '2020-01-02T18:21:03,322 | INFO  | safeCall-11      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF',
#  '2020-01-02T18:21:06,551 | INFO  | safeCall-12      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON',
#  '2020-01-02T18:21:07,849 | INFO  | safeCall-12      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF',
#  '2020-01-02T18:22:54,675 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON',
#  '2020-01-02T18:22:59,300 | INFO  | safeCall-16      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF',
#  '2020-01-02T18:23:07,975 | INFO  | safeCall-15      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON',
#  '2020-01-02T18:23:13,061 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF',
#  '2020-01-02T18:23:15,508 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON',
#  '2020-01-02T18:23:18,337 | INFO  | safeCall-17      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from ON to OFF',
#  '2020-01-02T18:23:24,763 | INFO  | safeCall-15      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | d1 changed from OFF to ON',
#  '2020-01-02T18:33:43,479 | INFO  | safeCall-26      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T18:33:44,782 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T18:33:46,334 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T18:33:47,129 | INFO  | safeCall-25      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T18:33:47,955 | INFO  | safeCall-26      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T18:33:51,081 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T18:33:53,099 | INFO  | safeCall-27      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T19:06:36,520 | INFO  | safeCall-34      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer2 changed from NULL to 100',
#  '2020-01-02T19:06:51,295 | INFO  | safeCall-36      | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer2 changed from 100 to 0',
#  '2020-01-02T19:16:59,802 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2020-01-02T19:17:03,435 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T19:17:05,306 | INFO  | safeCall-3       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T19:17:06,116 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T19:17:14,215 | INFO  | safeCall-3       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T19:17:15,858 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T19:17:16,628 | INFO  | safeCall-2       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T19:17:17,246 | INFO  | safeCall-2       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T19:17:17,921 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-02T19:17:18,558 | INFO  | safeCall-2       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-02T19:17:18,827 | INFO  | safeCall-1       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-03T10:32:09,139 | INFO  | safeCall-7       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2020-01-03T11:19:44,013 | INFO  | safeCall-9       | ItemStateChangedEvent            | 424 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | dimmer changed from 4 to 21',
#  '2020-01-03T11:41:24,725 | INFO  | safeCall-6       | ItemStateChangedEvent            | 432 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031131 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-03T11:43:00,619 | INFO  | safeCall-10      | ItemStateChangedEvent            | 432 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031131 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-03T11:43:37,570 | INFO  | safeCall-9       | ItemStateChangedEvent            | 432 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031131 | dimmer changed from 4 to 23',
#  '2020-01-03T14:30:01,696 | INFO  | safeCall-5       | ItemStateChangedEvent            | 436 - org.eclipse.smarthome.io.monitor - 0.11.0.202001021655 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-03T17:23:08,705 | INFO  | safeCall-3       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-03T17:23:21,879 | INFO  | safeCall-3       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from OFF to ON',
#  '2020-01-03T17:24:15,558 | INFO  | safeCall-1       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | dimmer changed from 23 to 44',
#  '2020-01-03T17:24:46,401 | INFO  | safeCall-3       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L5 changed from ON to OFF',
#  '2020-01-03T17:25:10,622 | INFO  | safeCall-1       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L5 changed from OFF to ON',
#  '2020-01-03T19:22:55,711 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | dimmer2 changed from NULL to 27',
#  '2020-01-06T11:51:55,722 | INFO  | safeCall-5       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L1 changed from OFF to ON',
#  '2020-01-06T12:14:17,366 | INFO  | safeCall-13      | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from NULL to ON',
#  '2020-01-06T12:30:05,572 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L3 changed from ON to OFF',
#  '2020-01-06T12:30:40,255 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:31:03,506 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:31:13,394 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:31:29,325 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:31:44,692 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | dimmer2 changed from NULL to 0',
#  '2020-01-06T12:32:12,558 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:33:13,343 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:33:17,230 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:33:19,219 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:33:22,459 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:33:43,539 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:34:13,507 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:34:15,446 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:34:21,143 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:34:22,304 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:34:43,627 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:34:53,329 | INFO  | safeCall-7       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF',
#  '2020-01-06T12:34:56,613 | INFO  | safeCall-8       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from OFF to ON',
#  '2020-01-06T12:35:02,885 | INFO  | safeCall-6       | ItemStateChangedEvent            | 439 - org.eclipse.smarthome.io.monitor - 0.11.0.202001031718 | 63_fueb1_Switch_L2 changed from ON to OFF']

# %%
df = pd.DataFrame([sub.split("|") for sub in m])

# %%
df.columns = ['time stamp', 'log type', 'call type', 'type state','log info','switch name with changed state']

# %%
df
# Out:
#                    time stamp log type           call type  \
# 0    2019-12-31T18:02:10,038    INFO     safeCall-7
# 1    2019-12-31T18:02:10,687    INFO     safeCall-7
# 2    2019-12-31T18:02:11,369    INFO     safeCall-7
# 3    2019-12-31T18:08:25,363    INFO     safeCall-3
# 4    2019-12-31T18:08:26,415    INFO     safeCall-3
# ..                        ...      ...                 ...
# 133  2020-01-06T12:34:22,304    INFO     safeCall-8
# 134  2020-01-06T12:34:43,627    INFO     safeCall-7
# 135  2020-01-06T12:34:53,329    INFO     safeCall-7
# 136  2020-01-06T12:34:56,613    INFO     safeCall-8
# 137  2020-01-06T12:35:02,885    INFO     safeCall-6
#
#                              type state  \
# 0     ItemStateChangedEvent
# 1     ItemStateChangedEvent
# 2     ItemStateChangedEvent
# 3     ItemStateChangedEvent
# 4     ItemStateChangedEvent
# ..                                  ...
# 133   ItemStateChangedEvent
# 134   ItemStateChangedEvent
# 135   ItemStateChangedEvent
# 136   ItemStateChangedEvent
# 137   ItemStateChangedEvent
#
#                                               log info  \
# 0     341 - org.eclipse.smarthome.io.monitor - 0.11...
# 1     341 - org.eclipse.smarthome.io.monitor - 0.11...
# 2     341 - org.eclipse.smarthome.io.monitor - 0.11...
# 3     342 - org.eclipse.smarthome.io.monitor - 0.11...
# 4     342 - org.eclipse.smarthome.io.monitor - 0.11...
# ..                                                 ...
# 133   439 - org.eclipse.smarthome.io.monitor - 0.11...
# 134   439 - org.eclipse.smarthome.io.monitor - 0.11...
# 135   439 - org.eclipse.smarthome.io.monitor - 0.11...
# 136   439 - org.eclipse.smarthome.io.monitor - 0.11...
# 137   439 - org.eclipse.smarthome.io.monitor - 0.11...
#
#                  switch name with changed state
# 0     63_fueb1_Switch_L1 changed from OFF to ON
# 1     63_fueb1_Switch_L2 changed from OFF to ON
# 2     63_fueb1_Switch_L3 changed from OFF to ON
# 3     63_fueb1_Switch_L2 changed from OFF to ON
# 4     63_fueb1_Switch_L1 changed from OFF to ON
# ..                                          ...
# 133   63_fueb1_Switch_L2 changed from ON to OFF
# 134   63_fueb1_Switch_L2 changed from OFF to ON
# 135   63_fueb1_Switch_L2 changed from ON to OFF
# 136   63_fueb1_Switch_L2 changed from OFF to ON
# 137   63_fueb1_Switch_L2 changed from ON to OFF
#
# [138 rows x 6 columns]

# %%
rdf = df[['time stamp','switch name with changed state']]

# %%
rdf
# Out:
#                    time stamp              switch name with changed state
# 0    2019-12-31T18:02:10,038    63_fueb1_Switch_L1 changed from OFF to ON
# 1    2019-12-31T18:02:10,687    63_fueb1_Switch_L2 changed from OFF to ON
# 2    2019-12-31T18:02:11,369    63_fueb1_Switch_L3 changed from OFF to ON
# 3    2019-12-31T18:08:25,363    63_fueb1_Switch_L2 changed from OFF to ON
# 4    2019-12-31T18:08:26,415    63_fueb1_Switch_L1 changed from OFF to ON
# ..                        ...                                         ...
# 133  2020-01-06T12:34:22,304    63_fueb1_Switch_L2 changed from ON to OFF
# 134  2020-01-06T12:34:43,627    63_fueb1_Switch_L2 changed from OFF to ON
# 135  2020-01-06T12:34:53,329    63_fueb1_Switch_L2 changed from ON to OFF
# 136  2020-01-06T12:34:56,613    63_fueb1_Switch_L2 changed from OFF to ON
# 137  2020-01-06T12:35:02,885    63_fueb1_Switch_L2 changed from ON to OFF
#
# [138 rows x 2 columns]

# %%
rdf['switch name with changed state'][0].split(" ")
# Out:
# ['', '63_fueb1_Switch_L1', 'changed', 'from', 'OFF', 'to', 'ON']

# %%
rdf['switch name with changed state'][0].split(" ")[1]
# Out:
# '63_fueb1_Switch_L1'

# %%
rdf['switch name with changed state'][0].split(" ")[4]+" "+rdf['switch name with changed state'][0].split(" ")[5]+" "+rdf['switch name with changed state'][0].split(" ")[6]
# Out:
# 'OFF to ON'

# %%
rdf["switch name"] = ""
rdf["changed state"] = ""
rdf["initial value"] = ""
rdf["final value"] = ""
# Out:
# /home/rajath/.virtualenvs/djangoapps/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/rajath/.virtualenvs/djangoapps/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/rajath/.virtualenvs/djangoapps/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(len(rdf)):
    rdf["switch name"][i] = rdf['switch name with changed state'][i].split(" ")[1]
    rdf["changed state"][i] = rdf['switch name with changed state'][i].split(" ")[4]+" "+rdf['switch name with changed state'][i].split(" ")[5]+" "+rdf['switch name with changed state'][i].split(" ")[6]
    rdf["initial value"][i] = rdf['switch name with changed state'][i].split(" ")[4]
    rdf["final value"][i] = rdf['switch name with changed state'][i].split(" ")[6]

# %%
rdf
# Out:
#                    time stamp              switch name with changed state  \
# 0    2019-12-31T18:02:10,038    63_fueb1_Switch_L1 changed from OFF to ON
# 1    2019-12-31T18:02:10,687    63_fueb1_Switch_L2 changed from OFF to ON
# 2    2019-12-31T18:02:11,369    63_fueb1_Switch_L3 changed from OFF to ON
# 3    2019-12-31T18:08:25,363    63_fueb1_Switch_L2 changed from OFF to ON
# 4    2019-12-31T18:08:26,415    63_fueb1_Switch_L1 changed from OFF to ON
# ..                        ...                                         ...
# 133  2020-01-06T12:34:22,304    63_fueb1_Switch_L2 changed from ON to OFF
# 134  2020-01-06T12:34:43,627    63_fueb1_Switch_L2 changed from OFF to ON
# 135  2020-01-06T12:34:53,329    63_fueb1_Switch_L2 changed from ON to OFF
# 136  2020-01-06T12:34:56,613    63_fueb1_Switch_L2 changed from OFF to ON
# 137  2020-01-06T12:35:02,885    63_fueb1_Switch_L2 changed from ON to OFF
#
#             switch name changed state initial value final value
# 0    63_fueb1_Switch_L1     OFF to ON           OFF          ON
# 1    63_fueb1_Switch_L2     OFF to ON           OFF          ON
# 2    63_fueb1_Switch_L3     OFF to ON           OFF          ON
# 3    63_fueb1_Switch_L2     OFF to ON           OFF          ON
# 4    63_fueb1_Switch_L1     OFF to ON           OFF          ON
# ..                  ...           ...           ...         ...
# 133  63_fueb1_Switch_L2     ON to OFF            ON         OFF
# 134  63_fueb1_Switch_L2     OFF to ON           OFF          ON
# 135  63_fueb1_Switch_L2     ON to OFF            ON         OFF
# 136  63_fueb1_Switch_L2     OFF to ON           OFF          ON
# 137  63_fueb1_Switch_L2     ON to OFF            ON         OFF
#
# [138 rows x 6 columns]

# %%
rdf.replace(('NULL','ON', 'OFF'), (0, 1, 0), inplace=True)

# %%
rdf
# Out:
#                    time stamp              switch name with changed state  \
# 0    2019-12-31T18:02:10,038    63_fueb1_Switch_L1 changed from OFF to ON
# 1    2019-12-31T18:02:10,687    63_fueb1_Switch_L2 changed from OFF to ON
# 2    2019-12-31T18:02:11,369    63_fueb1_Switch_L3 changed from OFF to ON
# 3    2019-12-31T18:08:25,363    63_fueb1_Switch_L2 changed from OFF to ON
# 4    2019-12-31T18:08:26,415    63_fueb1_Switch_L1 changed from OFF to ON
# ..                        ...                                         ...
# 133  2020-01-06T12:34:22,304    63_fueb1_Switch_L2 changed from ON to OFF
# 134  2020-01-06T12:34:43,627    63_fueb1_Switch_L2 changed from OFF to ON
# 135  2020-01-06T12:34:53,329    63_fueb1_Switch_L2 changed from ON to OFF
# 136  2020-01-06T12:34:56,613    63_fueb1_Switch_L2 changed from OFF to ON
# 137  2020-01-06T12:35:02,885    63_fueb1_Switch_L2 changed from ON to OFF
#
#             switch name changed state initial value final value
# 0    63_fueb1_Switch_L1     OFF to ON             0           1
# 1    63_fueb1_Switch_L2     OFF to ON             0           1
# 2    63_fueb1_Switch_L3     OFF to ON             0           1
# 3    63_fueb1_Switch_L2     OFF to ON             0           1
# 4    63_fueb1_Switch_L1     OFF to ON             0           1
# ..                  ...           ...           ...         ...
# 133  63_fueb1_Switch_L2     ON to OFF             1           0
# 134  63_fueb1_Switch_L2     OFF to ON             0           1
# 135  63_fueb1_Switch_L2     ON to OFF             1           0
# 136  63_fueb1_Switch_L2     OFF to ON             0           1
# 137  63_fueb1_Switch_L2     ON to OFF             1           0
#
# [138 rows x 6 columns]
